# %%
import pandas as pd
import time
# Load the CSV file
df = pd.read_csv("smart_logistic_tracker_japan.csv")

# Display the first 5 rows
df.head()
# Out:
#                     timestamp           carrier  tracking_number package_id  \
# 0  2026-05-04 13:50:26.857905  Yamato Transport     942646961460    PKG7545
# 1  2026-05-03 23:36:26.858095        Japan Post      74355111775    PKG2659
# 2  2026-05-04 08:32:26.858217        Japan Post     217497030475    PKG7965
# 3  2026-05-04 02:35:26.858332        Japan Post     249781996688    PKG5296
# 4  2026-05-04 08:28:26.858444        Japan Post     718415724062    PKG9987
#
#     origin             current_location delivery_location prefecture  \
# 0    Tokyo     Naha Central Post Office             Tokyo   Kanagawa
# 1    Tokyo   Nagoya Central Post Office             Kyoto   Kanagawa
# 2    Osaka   Nagoya Central Post Office             Osaka      Aichi
# 3  Fukuoka  Sapporo Central Post Office           Sapporo      Osaka
# 4  Fukuoka        Yokohama Sales Office           Sapporo   Hokkaido
#
#     latitude   longitude  ... waiting_time_minutes perishable  temperature  \
# 0  35.993159  139.038781  ...                   45         No         10.7
# 1  35.691292  139.130870  ...                   54        Yes          6.2
# 2  35.591109  139.784940  ...                  144        Yes         -3.1
# 3  35.570440  139.689163  ...                  173        Yes          6.3
# 4  35.679375  139.408071  ...                   82         No          0.7
#
#   humidity    rfid_tag  rfid_verified tamper_alert  traffic_status  \
# 0       40  RFID736892          False           No           Heavy
# 1       82  RFID156229          False          Yes          Detour
# 2       86  RFID890703           True          Yes           Heavy
# 3       87  RFID603182           True          Yes          Detour
# 4       60  RFID921432          False          Yes          Detour
#
#    inventory_level asset_utilization
# 0               99             84.59
# 1              363             53.39
# 2               25             95.75
# 3              145             63.84
# 4               34             56.28
#
# [5 rows x 25 columns]

# %%
from web3 import Web3

# Connect to local blockchain
ganache_url = "http://127.0.0.1:8545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0x5aeaC9323626b6843A4c011259B874E519681A1A"


# Paste the ABI from Remix
abi = [
  {
    "inputs": [],
    "stateMutability": "nonpayable",
    "type": "constructor"
  },
  {
    "anonymous": False,
    "inputs": [
      {
        "indexed": False,
        "internalType": "uint256",
        "name": "timestamp",
        "type": "uint256"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "currentLocation",
        "type": "string"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "status",
        "type": "string"
      }
    ],
    "name": "StatusUpdated",
    "type": "event"
  },
  {
    "inputs": [
      {
        "internalType": "string",
        "name": "_packageId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "_location",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "_status",
        "type": "string"
      }
    ],
    "name": "storeStatus",
    "outputs": [],
    "stateMutability": "nonpayable",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "uint256",
        "name": "index",
        "type": "uint256"
      }
    ],
    "name": "getPackageUpdate",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "getTotalRecords",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "name": "logisticsRecords",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "timestamp",
        "type": "uint256"
      },
      {
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "currentLocation",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "status",
        "type": "string"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "MAX_ENTRIES",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "owner",
    "outputs": [
      {
        "internalType": "address",
        "name": "",
        "type": "address"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  }
]  # Replace with your contract ABI

# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Set the default sender address (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x5aeaC9323626b6843A4c011259B874E519681A1A

# %%
def send_iot_data(package_id, location, status):
    """
    Sends logistics IoT data
    to the deployed smart contract
    """

    txn = contract.functions.storeStatus(
        package_id,
        location,
        status
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })

    # Wait for transaction confirmation
    receipt = web3.eth.wait_for_transaction_receipt(txn)

    print(
        f"✅ Data Stored | {package_id} | "
        f"Location: {location} | "
        f"Status: {status} | "
        f"Txn Hash: {receipt.transactionHash.hex()}"
    )

# Store 100 records
for index, row in df.head(100).iterrows():

    package_id = str(row["package_id"])
    location = str(row["current_location"])
    status = str(row["latest_status"])

    send_iot_data(package_id, location, status)

    # Delay between transactions
    time.sleep(1)

print("\n✅ Successfully stored 100 records on the blockchain!")
# Out:
# ✅ Data Stored | PKG7545 | Location: Naha Central Post Office | Status: Out for Delivery | Txn Hash: 92d24c19fdbb8d135a2951cc667bf8189dde2fb925c7ff52df9fffe4e4925e55
# ✅ Data Stored | PKG2659 | Location: Nagoya Central Post Office | Status: Arrival | Txn Hash: 6efdae5b3e3e663e3a6067e0f4baacfbe824fea112c50416218feaf36293ee90
# ✅ Data Stored | PKG7965 | Location: Nagoya Central Post Office | Status: Storage | Txn Hash: 07351ece38c2b960066c33917f8a9bd85dc5a0975bfcece275a0596ea7831581
# ✅ Data Stored | PKG5296 | Location: Sapporo Central Post Office | Status: Delivered to the delivery address | Txn Hash: c4b45e5f0a9f282808c608b645300de8dc4a6749fd1325908c930e57ab33c5bb
# ✅ Data Stored | PKG9987 | Location: Yokohama Sales Office | Status: Bring it back due to your absence | Txn Hash: 06c172b40e285dd8dea3dc2b092575e1e51a8472272e89099aa6032b9516e37d
# ✅ Data Stored | PKG8392 | Location: Nagoya Central Post Office | Status: Hold at Yamato | Txn Hash: a930b70cd01ef3a42f9a36e7c6be1ede90150df9836db272409d34b5be088b9f
# ✅ Data Stored | PKG2808 | Location: Naha Central Post Office | Status: Delay | Txn Hash: 7e15ca303c48907661a8f5ad93d3f16574e1bae1e5bd9996745161d2474f7742
# ✅ Data Stored | PKG1749 | Location: Fukuoka Distribution Center | Status: Arrival | Txn Hash: 7b0cea23882f04d293202fa5259b25e3adae84f10c9d83fcc064e87788fcde8c
# ✅ Data Stored | PKG8059 | Location: Fukuoka Distribution Center | Status: Out for Delivery | Txn Hash: 2c0598b4208333b3a069d3c4a18af505d381d036a1253264c8233832a40dfc14
# ✅ Data Stored | PKG7953 | Location: Nagoya Central Post Office | Status: Arrival | Txn Hash: 7444c79a1d1022a16003133927b2e54fcfdb47e7d4bd65d35cbb0eaa859850bc
# ✅ Data Stored | PKG2989 | Location: Yokohama Sales Office | Status: Bring it back due to your absence | Txn Hash: 7aca1c708459018343413597b6fd43dc4fd13d1f41802a034cad6daa232f5ba7
# ✅ Data Stored | PKG3002 | Location: Sapporo Central Post Office | Status: Out for Delivery | Txn Hash: 634e1b1eef65c9e8fba4f1272ef94a6cccb9389bf254b3427a9fa82915be4d8a
# ✅ Data Stored | PKG5872 | Location: Tokyo Central Post Office | Status: Arrival Scan | Txn Hash: b590c0253ec0fc1697269b68eba35d20b3ee443cb83c6decc7c1727255eb6474
# ✅ Data Stored | PKG8631 | Location: Naha Central Post Office | Status: Returned to the sender | Txn Hash: 3925a978524391bd1febe779f67d74721a92f8807fc0625279fcc3082863461e
# ✅ Data Stored | PKG1689 | Location: Osaka Central Post Office | Status: Arrival Scan | Txn Hash: be34ae469ae52e3c39e08db6ecdd6d486ac4da8acf1dedd7f73d8506f6952159
# ✅ Data Stored | PKG3400 | Location: Osaka Central Post Office | Status: Hand it over at the window | Txn Hash: 6209cefde6a49ebda0ecbf05829e6122b111fc8feb1d404a3e31215b2333c1c1
# ✅ Data Stored | PKG5481 | Location: Fukuoka Distribution Center | Status: Delivered to the delivery address | Txn Hash: 0cca48d22dec5c3c5c889616f9e2a8783cf6fd659af4be84938d7c91a1577197
# ✅ Data Stored | PKG7973 | Location: Naha Central Post Office | Status: Arrival Scan | Txn Hash: 990c61294bc200277343b4687d61691b2b85b24668f9b9d30dd59be300f32b45
# ✅ Data Stored | PKG5863 | Location: Naha Central Post Office | Status: Hand it over at the window | Txn Hash: 01b9d2beb41393dba53cb58540733820bd6201e56409a75298a6aa654ed36b02
# ✅ Data Stored | PKG3928 | Location: Naha Central Post Office | Status: Bring it back due to your absence | Txn Hash: a20016b68637a8c5b74d5ea736b9f1f72ec8b5ce4f25c1c9f31231a5f568355e
# ✅ Data Stored | PKG8254 | Location: Nagoya Central Post Office | Status: Delivered to the delivery address | Txn Hash: e233b9698365647c634e920f9ac683b8aefc28e2b4423d15a4ce464792729808
# ✅ Data Stored | PKG4344 | Location: Tokyo Central Post Office | Status: Returned | Txn Hash: cedd210fd934e5f2f6fc5066568105864f144c2fc84b84d81d38ba6b088607ab
# ✅ Data Stored | PKG9080 | Location: Sapporo Central Post Office | Status: Returned to the sender | Txn Hash: c5ea554bdc641c050437dddffb0f2c71954395b8a01428914d2037f379dba82a
# ✅ Data Stored | PKG7455 | Location: Fukuoka Distribution Center | Status: Delivered | Txn Hash: 995eef53001613bc54c002dab3a7849fe48c6a005659c60b85d1b8ef810510e8
# ✅ Data Stored | PKG8002 | Location: Tokyo Central Post Office | Status: Bring it back due to your absence | Txn Hash: 07197b4490fcdb1fc01d9842c111aa07b535087742d85bc355a0b2e054fa6939
# ✅ Data Stored | PKG6155 | Location: Sapporo Central Post Office | Status: Returned to the sender | Txn Hash: 2ed02fcafbd7c497e10161cf1e6940bdefda2aeecd4adddd2ebfa405b9cc9947
# ✅ Data Stored | PKG6108 | Location: Fukuoka Distribution Center | Status: Hold at Yamato | Txn Hash: d649719880d92f6535e02c8f9f6db70d3079fc60900820172d3e871bf2d06a77
# ✅ Data Stored | PKG2439 | Location: Yokohama Sales Office | Status: In Transit | Txn Hash: 4c461a541da83083736311e7f1fdb37f46f5185219388d86dd64f0b11881d4b0
# ✅ Data Stored | PKG3231 | Location: Naha Central Post Office | Status: Hand it over at the window | Txn Hash: 5b8c8e54495a6a79e73052427e11b9e97bde8b251a121a4773c325eb110c3130
# ✅ Data Stored | PKG3309 | Location: Sapporo Central Post Office | Status: Returned | Txn Hash: a102d66566fae46c173b5f5c0311282f6d175e9d2ab65b8129646c68b7cf3274
# ✅ Data Stored | PKG9257 | Location: Yokohama Sales Office | Status: Bring it back due to your absence | Txn Hash: 509af5fae94976fd86bb8a4531ff6b2592bd7f14e98ec19cac361a24c39f1432
# ✅ Data Stored | PKG1329 | Location: Osaka Central Post Office | Status: In Transit | Txn Hash: 79df5496ae844c340e43bcc938ea2b7178cafb1aad80287d45d5e9adf81cc739
# ✅ Data Stored | PKG6811 | Location: Osaka Central Post Office | Status: Hold at Yamato | Txn Hash: 9f244bd1f340d1fecee489c96a5df3404e0b14a0410f8204a1e2dad41efbec96
# ✅ Data Stored | PKG9244 | Location: Naha Central Post Office | Status: Returned to the sender | Txn Hash: f048cb6e80cd8d03851232d91a4784da05d1196a0648a1d252bdce05ec27fdba
# ✅ Data Stored | PKG1717 | Location: Tokyo Central Post Office | Status: Arrival | Txn Hash: 6e1710f6e66f144efc72858fde92994dba3d9324e7ce7b4a7295b6b8f19b2a7c
# ✅ Data Stored | PKG3405 | Location: Sapporo Central Post Office | Status: Under Investigation | Txn Hash: 4729560538a3602c10e6963721eb0a98b64807d429e0ce21820ea8e87c9ddf13
# ✅ Data Stored | PKG4781 | Location: Fukuoka Distribution Center | Status: Bring it back due to your absence | Txn Hash: d2b2aeef3087c5f6cb66f4544dddc66171d17565fb5ed6c99297f9e30f821842
# ✅ Data Stored | PKG9294 | Location: Sapporo Central Post Office | Status: Hand it over at the window | Txn Hash: 91979792c1886f591f082c20f4537ef6a0077c1979b96971101789cd987bfa65
# ✅ Data Stored | PKG2894 | Location: Naha Central Post Office | Status: Hand it over at the window | Txn Hash: 466b2ec7b201e6073254c4f86bfd571a46770b7eda92c8402966676dcdef15e7
# ✅ Data Stored | PKG6149 | Location: Nagoya Central Post Office | Status: Bring it back due to your absence | Txn Hash: 361e4b22fdda310e9f0f5bf606d8144016c1315ed83397234d3cfdd6b5fe8083
# ✅ Data Stored | PKG3680 | Location: Yokohama Sales Office | Status: Out for Delivery | Txn Hash: 3cc8b140b41ec212cb0dabc135625a5bf33e6f4b6d1a50d67400283415989980
# ✅ Data Stored | PKG8417 | Location: Tokyo Central Post Office | Status: Returned | Txn Hash: e4e0c32ed3faff8a729a58d047c45e085f3d89a16dd9e2e7047673a543e6f2c5
# ✅ Data Stored | PKG3150 | Location: Osaka Central Post Office | Status: Out for Delivery | Txn Hash: b4edba9e2f7ee8ede19ac8cfbec97f8f1e1adc5f769c55602477a6eccf1deda0
# ✅ Data Stored | PKG1198 | Location: Osaka Central Post Office | Status: Hold at Yamato | Txn Hash: c0aeab74654ea0733dc44328b18cfb906c9af6813f56ac630e7cbf2fc039fcc3
# ✅ Data Stored | PKG9015 | Location: Yokohama Sales Office | Status: Delay | Txn Hash: f64601fd343af07a82a19fb612e3d1e8462e9afe6f69db48f723c45b53fb984e
# ✅ Data Stored | PKG7192 | Location: Sapporo Central Post Office | Status: Delivered | Txn Hash: 6c73ed1a8696202842420a242d3b1bce45663c8fcd6256b7f7982a84cf4a819b
# ✅ Data Stored | PKG9742 | Location: Naha Central Post Office | Status: Hold at Yamato | Txn Hash: 30c6d31058e10104badfa54f62a492f3aff01abfae6fd049a74011e50e9f6c7c
# ✅ Data Stored | PKG7815 | Location: Naha Central Post Office | Status: Returned to the sender | Txn Hash: 57e1bb7b53cdd70f984a5b9c5dece90de92bd6ac0c29cb6e16b5f2a42e4c0fab
# ✅ Data Stored | PKG2329 | Location: Naha Central Post Office | Status: Hold at Yamato | Txn Hash: f1387d2cc328187fda0df8f05c85427d52cbd8965acde6d072f17a6e0ca148cf
# ✅ Data Stored | PKG6240 | Location: Osaka Central Post Office | Status: Hold at Yamato | Txn Hash: 25e02b2bd589d247643265fee41d4338d8e7585cd77dfa99eef51a8191c15197
# ✅ Data Stored | PKG6957 | Location: Yokohama Sales Office | Status: Returned to the sender | Txn Hash: 5b6759c0133932c489564ff8263cceb8aa7baab0ffaab4fc5bde3c80848d6bff
# ✅ Data Stored | PKG3165 | Location: Naha Central Post Office | Status: Returned | Txn Hash: c085295851c246786b672e523d9f5852f2d8c458c87aaab809e36ff8580f772c
#
# ✅ Successfully stored 100 records on the blockchain!

# %%
current_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {current_records}")
# Out:
# Total IoT records stored: 100

# %%
# Retrieve and display the first stored record
first_record = contract.functions.getPackageUpdate(0).call()

print("📦 First Stored Record")
print(f"Timestamp: {first_record[0]}")
print(f"Package ID: {first_record[1]}")
print(f"Location: {first_record[2]}")
print(f"Status: {first_record[3]}")
# Out:
# 📦 First Stored Record
# Timestamp: 1780070589
# Package ID: PKG7545
# Location: Naha Central Post Office
# Status: Out for Delivery

# %%
import config
from web3 import Web3

# Connect to Ganache (configured via .env or environment)
web3 = Web3(Web3.HTTPProvider(config.GANACHE_URL))

# Check connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed.")

# Contract address (loaded from .env via config.py)
contract_address = config.get_checksummed_address(web3)
if not contract_address:
    raise ValueError("CONTRACT_ADDRESS not set in .env or environment")

# Paste ABI here
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "dataValue",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_deviceId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_dataValue",
				"type": "string"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	}
]

# Load smart contract
contract = web3.eth.contract(
    address=contract_address,
    abi=abi
)

# Test contract function
total = contract.functions.getTotalRecords().call()

print("✅ Smart contract loaded successfully!")
print("Total Records:", total)

web3.eth.default_account = web3.eth.accounts[0]
print("Using account:", web3.eth.default_account)

# Store a dummy IoT data entry manually to test if transactions work

txn = contract.functions.storeData(
    "TEST001",
    "Temperature",
    "22.5C"
 ).transact({
    'from': web3.eth.default_account,
    'gas': 1000000
})

web3.eth.wait_for_transaction_receipt(txn)

print("✅ Dummy data stored on blockchain!")

total_records = contract.functions.getTotalRecords().call()
print(f"Total Records: {total_records}")


record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# ✅ Connected to Ganache successfully!
# ---------------------------------------------------------------------------
# InsufficientDataBytes                     Traceback (most recent call last)
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/web3/contract/utils.py:204, in call_contract_function(w3, address, normalizers, abi_element_identifier, transaction, block_id, contract_abi, abi_callable, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     203 try:
# --> 204     output_data = w3.codec.decode(output_types, return_data)
#     205 except DecodingError as e:
#     206     # Provide a more helpful error message than the one provided by
#     207     # eth-abi-utils
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/codec.py:162, in ABIDecoder.decode(self, types, data, strict)
#     160 stream = self.stream_class(data)
# --> 162 return cast(Tuple[Any, ...], decoder(stream))
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:131, in BaseDecoder.__call__(self, stream)
#     130 def __call__(self, stream: ContextFramesBytesIO) -> Any:
# --> 131     return self.decode(stream)
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_utils/functional.py:49, in apply_to_return_value.<locals>.outer.<locals>.inner(*args, **kwargs)
#      47 @functools.wraps(fn)
#      48 def inner(*args, **kwargs) -> T:  # type: ignore
# ---> 49     return callback(fn(*args, **kwargs))
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:224, in TupleDecoder.decode(self, stream)
#     222 @to_tuple
#     223 def decode(self, stream: ContextFramesBytesIO) -> Generator[Any, None, None]:
# --> 224     self.validate_pointers(stream)
#     225     for decoder in self.decoders:
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:218, in TupleDecoder.validate_pointers(self, stream)
#     215     else:
#     216         # the next 32 bytes are not a pointer, so progress the stream per
#     217         # the decoder
# --> 218         decoder(stream)
#     219 # return the stream to its original location for actual decoding
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:131, in BaseDecoder.__call__(self, stream)
#     130 def __call__(self, stream: ContextFramesBytesIO) -> Any:
# --> 131     return self.decode(stream)
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:250, in SingleDecoder.decode(self, stream)
#     249 def decode(self, stream):
# --> 250     raw_data = self.read_data_from_stream(stream)
#     251     data, padding_bytes = self.split_data_and_padding(raw_data)
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/eth_abi/decoding.py:389, in FixedByteSizeDecoder.read_data_from_stream(self, stream)
#     388 if len(data) != self.data_byte_size:
# --> 389     raise InsufficientDataBytes(
#     390         f"Tried to read {self.data_byte_size} bytes, "
#     391         f"only got {len(data)} bytes."
#     392     )
#     394 return data
#
# InsufficientDataBytes: Tried to read 32 bytes, only got 0 bytes.
#
# The above exception was the direct cause of the following exception:
#
# BadFunctionCallOutput                     Traceback (most recent call last)
# Cell In[2], line 195
#     191     abi=abi
#     192 )
#     193
#     194 # Test contract function
# --> 195 total = contract.functions.getTotalRecords().call()
#     196
#     197 print("✅ Smart contract loaded successfully!")
#     198 print("Total Records:", total)
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/web3/contract/contract.py:291, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     287 block_id = parse_block_identifier(self.w3, block_identifier)
#     289 abi_element_identifier = abi_to_signature(self.abi)
# --> 291 return call_contract_function(
#     292     self.w3,
#     293     self.address,
#     294     self._return_data_normalizers,
#     295     abi_element_identifier,
#     296     call_transaction,
#     297     block_id,
#     298     self.contract_abi,
#     299     self.abi,
#     300     state_override,
#     301     ccip_read_enabled,
#     302     self.decode_tuples,
#     303     *self.args or (),
#     304     **self.kwargs or {},
#     305 )
#
# File ~/codestuff/MMDC/ADET/adet/.venv/lib/python3.14/site-packages/web3/contract/utils.py:222, in call_contract_function(w3, address, normalizers, abi_element_identifier, transaction, block_id, contract_abi, abi_callable, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     217     else:
#     218         msg = (
#     219             f"Could not decode contract function call to {abi_element_identifier} "
#     220             f"with return data: {str(return_data)}, output_types: {output_types}"
#     221         )
# --> 222     raise BadFunctionCallOutput(msg) from e
#     224 _normalizers = itertools.chain(
#     225     BASE_RETURN_NORMALIZERS,
#     226     normalizers,
#     227 )
#     228 normalized_data = map_abi_data(_normalizers, output_types, output_data)
#
# BadFunctionCallOutput: Could not transact with/call contract function, is contract deployed correctly and chain synced?
